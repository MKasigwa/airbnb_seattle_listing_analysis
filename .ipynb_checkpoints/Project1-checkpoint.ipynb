# %% [markdown]
# ### A look at the data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

reviews_df = pd.read_csv('./reviews.csv')
reviews_df.head()
# Out:
#    listing_id        id        date  reviewer_id reviewer_name  \
# 0     7202016  38917982  2015-07-19     28943674        Bianca
# 1     7202016  39087409  2015-07-20     32440555         Frank
# 2     7202016  39820030  2015-07-26     37722850           Ian
# 3     7202016  40813543  2015-08-02     33671805        George
# 4     7202016  41986501  2015-08-10     34959538          Ming
#
#                                             comments
# 0  Cute and cozy place. Perfect location to every...
# 1  Kelly has a great room in a very central locat...
# 2  Very spacious apartment, and in a great neighb...
# 3  Close to Seattle Center and all it has to offe...
# 4  Kelly was a great host and very accommodating ...

# %%
listing_df = pd.read_csv('./listings.csv')
listing_df.head()
# Out:
#         id                           listing_url       scrape_id last_scraped  \
# 0   241032   https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 1   953595   https://www.airbnb.com/rooms/953595  20160104002432   2016-01-04
# 2  3308979  https://www.airbnb.com/rooms/3308979  20160104002432   2016-01-04
# 3  7421966  https://www.airbnb.com/rooms/7421966  20160104002432   2016-01-04
# 4   278830   https://www.airbnb.com/rooms/278830  20160104002432   2016-01-04
#
#                                   name  \
# 0         Stylish Queen Anne Apartment
# 1   Bright & Airy Queen Anne Apartment
# 2  New Modern House-Amazing water view
# 3                   Queen Anne Chateau
# 4       Charming craftsman 3 bdm house
#
#                                              summary  \
# 0                                                NaN
# 1  Chemically sensitive? We've removed the irrita...
# 2  New modern house built in 2013.  Spectacular s...
# ...

# %% [markdown]
# ### Look at data infos to display columns and their data types

# %%
listing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 92 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                3818 non-null   int64
#  1   listing_url                       3818 non-null   object
#  2   scrape_id                         3818 non-null   int64
#  3   last_scraped                      3818 non-null   object
#  4   name                              3818 non-null   object
#  5   summary                           3641 non-null   object
#  6   space                             3249 non-null   object
#  7   description                       3818 non-null   object
#  8   experiences_offered               3818 non-null   object
#  9   neighborhood_overview             2786 non-null   object
#  10  notes                             2212 non-null   object
# ...

# %% [markdown]
# Overwrite host_since column after casting it to a datetime data type so we could do listings host since

# %%
listing_df["host_since"] = pd.to_datetime(listing_df["host_since"])

# %% [markdown]
# Overwrite price column after casting it to a numeric data type so we could calculate the average price of Airbnb listings.

# %%
listing_df['price']=listing_df['price'].str.replace('$','',regex=False).str.replace(',','',regex=False).astype(float)

# %%
listing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 92 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                3818 non-null   int64
#  1   listing_url                       3818 non-null   object
#  2   scrape_id                         3818 non-null   int64
#  3   last_scraped                      3818 non-null   object
#  4   name                              3818 non-null   object
#  5   summary                           3641 non-null   object
#  6   space                             3249 non-null   object
#  7   description                       3818 non-null   object
#  8   experiences_offered               3818 non-null   object
#  9   neighborhood_overview             2786 non-null   object
#  10  notes                             2212 non-null   object
# ...

# %% [markdown]
# You can now notice that host_since and price columns are stored respectively as datetime and numeric (float) data types.

# %%
listing_df['room_type'].value_counts()
# Out:
# room_type
# Entire home/apt    2541
# Private room       1160
# Shared room         117
# Name: count, dtype: int64

# %%
listing_df['price'].mean()
# Out:
# 127.97616553169199

# %% [markdown]
# #### We will focus on data where city equals seattle and just some columns that are capital of our analysis.

# %% [markdown]
# Looking at data type over columns

# %%
seatle_listings = listing_df.query("city == 'Seattle'").loc[:,["host_since","city","neighbourhood","accommodates","price","number_of_reviews"]]
seatle_listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3810 entries, 0 to 3817
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   host_since         3808 non-null   datetime64[ns]
#  1   city               3810 non-null   object
#  2   neighbourhood      3398 non-null   object
#  3   accommodates       3810 non-null   int64
#  4   price              3810 non-null   float64
#  5   number_of_reviews  3810 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(2)
# memory usage: 208.4+ KB

# %% [markdown]
# #### Check for missing values and calculate the minimum, maximum, and average for each numeric field

# %% [markdown]
#  ### Host_since datatype conversion
# The host since column looks like a date but when you take a look at info method we see that it is stored as an object datatype
# The have to fix it to look like a datatime datatype by overiding it

# %%
seatle_listings.isna().sum()
# Out:
# host_since             2
# city                   0
# neighbourhood        412
# accommodates           0
# price                  0
# number_of_reviews      0
# dtype: int64

# %% [markdown]
# ### Check missing values

# %% [markdown]
# ### Minimum and Maximum average of our numeric columns

# %%
seatle_listings.describe()
# Out:
#                           host_since  accommodates        price  \
# count                           3808   3810.000000  3810.000000
# mean   2013-09-18 04:40:12.605041920      3.350656   128.052231
# min              2008-11-10 00:00:00      1.000000    20.000000
# 25%              2012-08-15 00:00:00      2.000000    75.000000
# 50%              2013-12-12 00:00:00      3.000000   100.000000
# 75%              2015-01-14 00:00:00      4.000000   150.000000
# max              2016-01-03 00:00:00     16.000000  1000.000000
# std                              NaN      1.978058    90.317390
#
#        number_of_reviews
# count        3810.000000
# mean           22.222310
# min             0.000000
# 25%             2.000000
# 50%             9.000000
# 75%            26.000000
# max           474.000000
# std            37.758517

# %% [markdown]
# Group listings by neigbourhood and calculate the average price of each. Sort by price in ascending order.

# %%
seatle_listings_neighbourdhood_price = (seatle_listings.groupby('neighbourhood').agg({"price":"mean"}).sort_values("price"))
seatle_listings_neighbourdhood_price.head()
# Out:
#                    price
# neighbourhood
# Roxhill        60.000000
# Olympic Hills  63.666667
# Dunlap         75.461538
# Rainier Beach  76.722222
# Georgetown     77.000000

# %% [markdown]
# Group listings by neigbourhood and calculate the average accomodate of each. Sort by accommodate in ascending order.

# %%
seatle_listings_neighbourdhood_accommodate = (seatle_listings.groupby('neighbourhood').agg({"accommodates":"mean"}).sort_values("accommodates"))
seatle_listings_neighbourdhood_accommodate.head()
# Out:
#                     accommodates
# neighbourhood
# Olympic Hills           1.750000
# North College Park      2.000000
# Roxhill                 2.000000
# Victory Heights         2.230769
# High Point              2.272727

# %%
(seatle_listings_neighbourdhood_price.plot.barh(title = "Average Listing Price by Seattle Neignbourhood"))
sns.despine()

# %%
(seatle_listings_neighbourdhood_accommodate.plot.barh(title = "Average Listing Accommodate by Seattle Neignbourhood"))
sns.despine()

# %%
seatle_listings_neighbourdhood.tail() #Most accomodated neighbourhood
# Out:
#                    accommodates
# neighbourhood
# South Beacon Hill      5.000000
# South Park             5.000000
# Portage Bay            5.071429
# Pinehurst              6.666667
# Fairmount Park         8.000000

# %%
seatle_listings.head()
# Out:
#    host_since neighbourhood     city  accommodates    price  number_of_reviews
# 0  2011-08-11    Queen Anne  Seattle             4   $85.00                207
# 1  2013-02-21    Queen Anne  Seattle             4  $150.00                 43
# 2  2014-06-12    Queen Anne  Seattle            11  $975.00                 20
# 3  2013-11-06    Queen Anne  Seattle             3  $100.00                  0
# 4  2011-11-29    Queen Anne  Seattle             6  $450.00                 38

# %% [markdown]
# chart that displays th count of host over time and one for average price

# %%
seatle_listings_over_time = (seatle_listings.set_index("host_since").resample("Y").agg({
    "neighbourhood":"count","price":"mean"
}))
seatle_listings_over_time.head()
# Out:
#             neighbourhood       price
# host_since
# 2008-12-31              4   79.500000
# 2009-12-31             59  125.750000
# 2010-12-31            143  144.167785
# 2011-12-31            371  140.510050
# 2012-12-31            505  124.920223

# %%
seatle_listings_over_time["neighbourhood"].plot(ylabel="New Hosts",title="New AirBnb Hosts in Paris Over Time")
sns.despine()

# %% [markdown]
# Have a look on the average price over time

# %%
seatle_listings_over_time["price"].plot(ylabel="Average Price",title="Average AirBnb Price Over Time")
sns.despine()

# %% [markdown]
# dual axis chart, we have the average price represented in our right Axis and new host represented in our left axis.

# %%
fig,ax = plt.subplots()
ax.plot(seatle_listings_over_time.index,
        seatle_listings_over_time["neighbourhood"],
        label="New Hosts",
        c="red")
ax.set_ylabel("New Hosts")
ax2 = ax.twinx()
ax2.plot(seatle_listings_over_time.index,
        seatle_listings_over_time["price"],
        label="Average Price",
        c="blue")
ax2.set_ylabel("Average Price")
# Out:
# Text(0, 0.5, 'Average Price')

# %%
seatle_listings_accommodates = (seatle_listings.query("neighbourhood =='Queen Anne'").groupby("price").agg({"accommodates":"mean","neighbourhood":"count"}).sort_values("accommodates"))
seatle_listings_accommodates.head()
# Out:
#        accommodates  neighbourhood
# price
# 45.0            1.5              2
# 117.0           2.0              1
# 142.0           2.0              1
# 105.0           2.0              1
# 209.0           2.0              2

# %%
seatle_listings["host_since"] = pd.to_datetime(seatle_listings["host_since"])
seatle_listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3810 entries, 0 to 3817
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   host_since         3808 non-null   datetime64[ns]
#  1   city               3810 non-null   object
#  2   neighbourhood      3398 non-null   object
#  3   accommodates       3810 non-null   int64
#  4   price              3810 non-null   float64
#  5   number_of_reviews  3810 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(2)
# memory usage: 208.4+ KB

# %%
seatle_listings_over_time = (seatle_listings.set_index("host_since").resample("Y").agg({
    "neighbourhood":"count","accommodates":"mean"
}))
seatle_listings_over_time.head()
# Out:
#             neighbourhood  accommodates
# host_since
# 2008-12-31              4      2.500000
# 2009-12-31             59      3.406250
# 2010-12-31            143      3.885906
# 2011-12-31            371      3.731156
# 2012-12-31            505      3.378479

# %%
(seatle_listings_neighbourdhood.plot.barh(title = "Average Listing accomodate by Seattle Neignbourhood"))
sns.despine()

# %%
import seaborn as sns
(seatle_listings_accommodates.plot.barh(title = "Average Listing accomodate by Seattle Neignbourhood"))
sns.despine()

# %%
import seaborn as sns
(seatle_listings_over_time["accommodates"].plot(ylabel="Average accomodate",title="Average AirBnB Accomodate in Seattle Over Time:)
sns.despine()

# %%
(seatle_listings_over_time["neighbourhood"].plot(title = "New AirBnb Hosts in Seatle Over Time"))
sns.despine()

# %%
fig,ax = plt.subplots()
ax.plot(seatle_listings_over_time.index,
        seatle_listings_over_time["neighbourhood"],
        label="New Hosts",
        c="red")
ax.set_ylabel("New Hosts")
ax2 = ax.twinx()
ax2.plot(seatle_listings_over_time.index,
        seatle_listings_over_time["accommodates"],
        label="Average accommodate",
        c="blue")
ax2.set_ylabel("Average accomodate")
# Out:
# Text(0, 0.5, 'Average accomodate')

# %%
calendar_df = pd.read_csv('./calendar.csv')
calendar_df.head()
# Out:
#    listing_id        date available   price
# 0      241032  2016-01-04         t  $85.00
# 1      241032  2016-01-05         t  $85.00
# 2      241032  2016-01-06         f     NaN
# 3      241032  2016-01-07         f     NaN
# 4      241032  2016-01-08         f     NaN

# %% [markdown]
# I check which columns have the most mission values (more than 75%) for each dataframe.

# %%
reviews_df.columns[np.sum(reviews_df.isnull())/df.shape[0] >.75]
# Out:
# Index([], dtype='object')

# %% [markdown]
# Looks like no column that have more than 75% of missing values

# %%
listing_df.columns[np.sum(listing_df.isnull())/df.shape[0] >.75]
# Out:
# Index([], dtype='object')

# %%
calendar_df.columns[np.sum(calendar_df.isnull())/df.shape[0] >.75]
# Out:
# Index(['price'], dtype='object')

# %% [markdown]
# From the calendar dataframe, the price column misses more than 75% of its values.

# %%
### Q1. Merge all tree dataframes to get one single dataframe

# %%
status_vals = reviews_df['listing_id'].value_counts()
(status_vals/df.shape[0]).plot(kind="bar");
plt.title("Listing review frequency")
# Out:
# Text(0.5, 1.0, 'Listing review frequency')

# %%
status_vals = listing_df['jurisdiction_names'].value_counts()
(status_vals/df.shape[0]).plot(kind="bar");
plt.title("Reviewers")
# Out:
# Text(0.5, 1.0, 'Reviewers')

# %%
status_vals2 = listing_df['cancellation_policy'].value_counts()
(status_vals2/df.shape[0]).plot(kind="bar");
plt.title("Cancellation policies")
# Out:
# Text(0.5, 1.0, 'Cancellation policies')

# %%
seatle_listings['price'].mean()
# Out:
# 128.0522309711286
